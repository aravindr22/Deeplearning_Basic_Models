# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib as pllt
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sn

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train/255
X_test = X_test/255

# %%
X_train_flatten = X_train.reshape(len(X_train),28*28)
X_test_flatten = X_test.reshape(len(X_test),28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,), activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_flatten, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4715 - accuracy: 0.8766: 0s - loss: 0.4744 - accuracy: 0.87
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3045 - accuracy: 0.9149: 0s - loss:
# Epoch 3/5
# 1875/1875 [==============================] - 2s 984us/step - loss: 0.2831 - accuracy: 0.9213
# Epoch 4/5
# 1875/1875 [==============================] - 2s 981us/step - loss: 0.2731 - accuracy: 0.92410s - loss: 0.2739 - accura
# Epoch 5/5
# 1875/1875 [==============================] - 2s 985us/step - loss: 0.2664 - accuracy: 0.9258

# %%
model.evaluate(X_test_flatten, y_test)
# Out:
# 313/313 [==============================] - 0s 790us/step - loss: 0.2682 - accuracy: 0.9268
# [0.26818597316741943, 0.926800012588501]

# %%
y_predicted = model.predict(X_test_flatten)

# %%
plt.matshow(X_test[0])

# %%
np.argmax(y_predicted[0])
# Out:
# 7

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('label')
# Out:
# Text(69.0, 0.5, 'label')

# %%
#The below nerual network is desgined using hidden layer

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,) ,activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_flatten, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2741 - accuracy: 0.9215
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1205 - accuracy: 0.9648
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0850 - accuracy: 0.9756
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0653 - accuracy: 0.9800
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0518 - accuracy: 0.9840

# %%
model.evaluate(X_test_flatten,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9722
# [0.09536717087030411, 0.9721999764442444]

# %%
y_predicted = model.predict(X_test_flatten)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('label')
# Out:
# Text(69.0, 0.5, 'label')

# %%
#Using keras inbuilt flatten method

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train, y_train, epochs=5)
